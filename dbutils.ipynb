# %%
# %fs
ls dbfs:/databricks-datasets/

# %%
dbutils.fs.ls("/databricks-datasets/COVID/coronavirusdataset/")

# %%
for f in dbutils.fs.ls("/databricks-datasets"):
  print(f.path)

for f in dbutils.fs.ls("/databricks-datasets"):
  print(f.name)

# %%
df = spark.read.csv("dbfs:/databricks-datasets/COVID/coronavirusdataset/")
df.count()

# %%
dbutils.notebook.help()

# %%
# dbutils.notebook.run("/path",timeoutsencnds,arguments)
dbutils.notebook.run("/Learnbydoingit/Dileep_Databricks/child notebook",40,{"parameter1":"John"})

# %%
# %fs mounts
