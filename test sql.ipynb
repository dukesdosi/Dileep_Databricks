# %%
# %sql
GRANT CREATE, USAGE ON SCHEMA data_dev.etl TO <pipeline_role>;
GRANT SELECT, MODIFY ON SCHEMA data_dev.etl TO <pipeline_role>;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS data_dev.etl;

# %%
# %sql
select * from data_dev.bronze.customers_raw;

# %%
# %sql
select count(*) from data_dev.bronze.customers_raw;
select count(c_custkey) from data_dev.bronze.customers_raw;
