# %%
# %sql
CREATE SCHEMA IF NOT EXISTS data_dev.etl
COMMENT 'Schema for DLT ETL';

CREATE SCHEMA IF NOT EXISTS data_dev.bronze
COMMENT 'Schema for DLT ETL';

# %%
# %sql
--clone some sample tables
CREATE TABLE IF NOT EXISTS data_dev.bronze.orders_raw DEEP CLONE samples.tpch.orders;
CREATE TABLE IF NOT EXISTS data_dev.bronze.customers_raw DEEP CLONE samples.tpch.customer;
