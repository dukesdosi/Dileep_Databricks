# %%
# %sql
create table data_dev.default.test_managed(
  id int,
  name string
)
using delta

# %%
# %sql
insert into data_dev.default.test_managed values(1,"Dileep")

# %%
# %sql
select * from data_dev.default.test_managed;

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
SHOW SCHEMAS IN data_dev;

# %%
# %sql
DESCRIBE CATALOG data_dev;

# %%
# %sql
SHOW TABLES IN data_dev.default;
