# %%
print("Printing from child notebook !!!")

# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("Parameter1","","This is a text widget")

# %%
para1=dbutils.widgets.get("Parameter1")
print(para1)

# %%
print("I'm chld notebook and received the parameter "+para1+" from child notebook")

# %%
dbutils.notebook.exit("This is an exit message from child notebook")
