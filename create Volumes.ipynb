# %%
# %sql
create volume data_dev.default.test_volume

-- drop volume data_dev.default.test_volume

# %%
# %sql
create external volume data_dev.default.test_volume
location 'dbfs:/FileStore/shared_uploads/test_volume'
